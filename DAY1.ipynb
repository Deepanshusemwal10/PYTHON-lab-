# %% [markdown]
# <a href="https://colab.research.google.com/github/Deepanshusemwal10/PYTHON-lab-/blob/main/DAY1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
name = "Deepanshu"
print(name )
age = 18
print(age)
account_balance = 0.55
print(account_balance)
# Out:
# Deepanshu
# 18
# 0.55

# %%
a="deepanshu"
b="deepu"
c="semwal"
d=a+b+c
print(d)
# Out:
# deepanshudeepusemwal

# %%
a="hello"
b="john"
c=a+b
print(c)
# Out:
# hellojohn

# %%
a=input("NAME:")
b=input("SAP ID:")
C=input("DOB:")
d=input("ADDRESS")
e=input("PROGRAMME")
f=input("SEMESTER")
print("NAME:",a)
print("SAP ID:",b)
print("DATE OF BIRTH:",c)
print("ADDRESS:",d)
print("PROGRAMME:",e)
print("SEMESTER:",f)
# Out:
# NAME:deepanshu
# SAP ID:590016618
# DOB:17\01\2007
# ADDRESSpondha Dehradun uttrakhand
# PROGRAMMEcse
# SEMESTER4
# NAME: deepanshu
# SAP ID: 590016618
# DATE OF BIRTH: hellojohn
# ADDRESS: pondha Dehradun uttrakhand
# PROGRAMME: cse
# SEMESTER: 4
